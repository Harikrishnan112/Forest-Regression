# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib

data=pd.read_csv("Iris.csv")

x=data.drop(columns=["Id","Species"])
y=data[["Species"]].values.ravel()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)

model=RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(x_train,y_train)

y_predict_train=model.predict(x_train)
joblib.dump(model,"rf-machine.joblib")
new_data1=[5.0, 3.6, 1.4, 0.2]
new_data2=[6.1, 2.8, 4.0, 1.3]
new_data3=[6.9, 3.1, 5.4, 2.1]

new_data_for_prediction = pd.DataFrame([new_data3],columns=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"])

y_predict=model.predict(new_data_for_prediction)

print("The flower is",y_predict[0])
print("Training has completed and model file generated")
# Out:
# The flower is Iris-virginica
# Training has completed and model file generated
